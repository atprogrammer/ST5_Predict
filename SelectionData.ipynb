# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('../../../../../../Users/kanoksak/Desktop/Tableau/MHCI/mhci.csv', parse_dates=['data_create'])
# Out:
# <ipython-input-50-669c19b8a63a>:1: DtypeWarning: Columns (3,4,5,6,8,9,10,14,39,40,41,43,44,87,91,95,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../../../../Users/kanoksak/Desktop/Tableau/MHCI/mhci.csv', parse_dates=['data_create'])

# %%
df['data_create'] = pd.to_datetime(df['data_create'],infer_datetime_format=True)

# %%
df = df.loc[(df['data_create'] >= '2021-10-01')]
                    # & (df['data_create'] < '2022-04-01')]

# %%
df=df[['gender','people_type','age','risk_group1','risk_group2','risk_group3','risk_group4','risk_group5','risk_group6','risk_group7',
'risk_group8','risk_group9','risk_group10','risk_group11','risk_group12','risk_group13','risk_group14','risk_group15','risk_group16','risk_group17','rq1','rq2','rq3','st_5']]

df.head()
# Out:
#        gender           people_type  age  risk_group1  risk_group2  \
# 631939    ชาย               ประชาชน   54            0            0
# 631940   หญิง               ประชาชน   50            0            0
# 631941   หญิง                   อสม   56            0            0
# 631942   หญิง               ประชาชน   39            0            0
# 631943   หญิง  เจ้าหน้าที่สาธารณสุข   24            0            0
#
#         risk_group3  risk_group4  risk_group5  risk_group6  risk_group7  ...  \
# 631939            0            0            0            0            0  ...
# 631940            0            0            0            0            0  ...
# 631941            0            0            0            0            0  ...
# 631942            0            0            0            6            0  ...
# 631943            0            0            0            0            0  ...
#
#         risk_group12  risk_group13  risk_group14  risk_group15  risk_group16  \
# ...

# %%
df.shape
# Out:
# (2127457, 24)

# %%
df.describe()
# Out:
#                 age   risk_group1   risk_group2   risk_group3   risk_group4  \
# count  2.127457e+06  2.127457e+06  2.127457e+06  2.127457e+06  2.127457e+06
# mean   4.834713e+01  4.352614e-02  2.240938e-02  1.477736e-01  1.092140e-01
# std    1.734046e+01  2.040383e-01  2.105118e-01  6.492180e-01  6.518653e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.500000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    5.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    6.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.500000e+02  1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
#
#         risk_group5   risk_group6   risk_group7   risk_group8   risk_group9  \
# count  2.127457e+06  2.127457e+06  2.127457e+06  2.127457e+06  2.127457e+06
# mean   1.425552e-01  7.965623e-01  1.515306e+00  2.009021e+00  1.880179e-06
# ...

# %%
df.isna().sum()
# Out:
# gender          112
# people_type     131
# age               0
# risk_group1       0
# risk_group2       0
# risk_group3       0
# risk_group4       0
# risk_group5       0
# risk_group6       0
# risk_group7       0
# risk_group8       0
# risk_group9       0
# risk_group10      0
# risk_group11      0
# risk_group12      0
# risk_group13      0
# risk_group14      0
# risk_group15      0
# risk_group16      0
# risk_group17      0
# rq1               0
# rq2               0
# rq3               0
# st_5              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# gender          0
# people_type     0
# age             0
# risk_group1     0
# risk_group2     0
# risk_group3     0
# risk_group4     0
# risk_group5     0
# risk_group6     0
# risk_group7     0
# risk_group8     0
# risk_group9     0
# risk_group10    0
# risk_group11    0
# risk_group12    0
# risk_group13    0
# risk_group14    0
# risk_group15    0
# risk_group16    0
# risk_group17    0
# rq1             0
# rq2             0
# rq3             0
# st_5            0
# dtype: int64

# %%
df = df.drop(df[(df.age < 0) | (df.age > 100)].index)

# %%
df=df.loc[(df['people_type'] == "ประชาชน") | (df['people_type'] == "อสม") | (df['people_type'] == "เจ้าหน้าที่สาธารณสุข")| (df['people_type'] == "เจ้าหน้าที่หน่วยงานสังกัดอื่น")| (df['people_type'] == "บุคคลากรทางการศึกษา")| (df['people_type'] == "พระภิกษุ/สามเณร/นักบวช/ผู้นำศาสนา")| (df['people_type'] == "ผู้สัมผัสเสี่ยงสูง")]

# %%
df.groupby(['people_type']).count()
# Out:
#                                     gender      age  risk_group1  risk_group2  \
# people_type
# บุคคลากรทางการศึกษา                  40549    40549        40549        40549
# ประชาชน                            1634999  1634999      1634999      1634999
# ผู้สัมผัสเสี่ยงสูง                   16913    16913        16913        16913
# พระภิกษุ/สามเณร/นักบวช/ผู้นำศาสนา     3023     3023         3023         3023
# อสม                                 317044   317044       317044       317044
# เจ้าหน้าที่สาธารณสุข                 86994    86994        86994        86994
# เจ้าหน้าที่หน่วยงานสังกัดอื่น        27626    27626        27626        27626
#
#                                    risk_group3  risk_group4  risk_group5  \
# people_type
# บุคคลากรทางการศึกษา                      40549        40549        40549
# ประชาชน                                1634999      1634999      1634999
# ผู้สัมผัสเสี่ยงสูง                       16913        16913        16913
# ...

# %%
df.loc[df["gender"] == "ประชาชนชาย", "gender"] = "ชาย"
df.loc[df["gender"] == "ประชาชนหญิ", "gender"] = "หญิง"
df.groupby(['gender']).count()
# Out:
#         people_type      age  risk_group1  risk_group2  risk_group3  \
# gender
# ชาย          827939   827939       827939       827939       827939
# หญิง        1299209  1299209      1299209      1299209      1299209
#
#         risk_group4  risk_group5  risk_group6  risk_group7  risk_group8  ...  \
# gender                                                                   ...
# ชาย          827939       827939       827939       827939       827939  ...
# หญิง        1299209      1299209      1299209      1299209      1299209  ...
#
#         risk_group12  risk_group13  risk_group14  risk_group15  risk_group16  \
# gender
# ชาย           827939        827939        827939        827939        827939
# หญิง         1299209       1299209       1299209       1299209       1299209
#
#         risk_group17      rq1      rq2      rq3     st_5
# gender
# ชาย           827939   827939   827939   827939   827939
# หญิง         1299209  1299209  1299209  1299209  1299209
#
# ...

# %%
df1_1= df.loc[df['st_5'] >=8]  #คัดเลือก 1/2
for i in range(1000):
    df1_2 = df1_1.take(np.random.permutation(len(df1_1))[:36400])

# %%
df1_2.shape
# Out:
# (36400, 24)

# %%
df2_1= df.loc[df['st_5'] <8] #คัดเลือก 1/2
for i in range(1000):
    df2_2 = df2_1.take(np.random.permutation(len(df2_1))[:36400])

# %%
df2_2.shape
# Out:
# (36400, 24)

# %%
df=df1_2.append(df2_2)
df.shape
# Out:
# <ipython-input-67-925d04d78cd0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1_2.append(df2_2)
# (72800, 24)

# %%
dummies = pd.get_dummies(df['gender'])
df = pd.concat([df, dummies], axis = 1)
df
# Out:
#         gender people_type  age  risk_group1  risk_group2  risk_group3  \
# 2464369   หญิง     ประชาชน   13            0            0            0
# 2589400   หญิง     ประชาชน   25            0            0            0
# 2428662   หญิง     ประชาชน   15            0            0            0
# 4020730    ชาย     ประชาชน   32            0            2            0
# 4393684   หญิง     ประชาชน   24            1            0            0
# ...        ...         ...  ...          ...          ...          ...
# 4027289    ชาย     ประชาชน   26            0            0            0
# 3381966   หญิง     ประชาชน   33            0            0            0
# 3708319   หญิง     ประชาชน   80            0            0            0
# 3662819   หญิง     ประชาชน   15            0            0            0
# 4026098   หญิง     ประชาชน   27            0            0            0
#
#          risk_group4  risk_group5  risk_group6  risk_group7  ...  \
# ...

# %%
dummies = pd.get_dummies(df['people_type'])
df = pd.concat([df, dummies], axis = 1)
df
# Out:
#         gender people_type  age  risk_group1  risk_group2  risk_group3  \
# 2464369   หญิง     ประชาชน   13            0            0            0
# 2589400   หญิง     ประชาชน   25            0            0            0
# 2428662   หญิง     ประชาชน   15            0            0            0
# 4020730    ชาย     ประชาชน   32            0            2            0
# 4393684   หญิง     ประชาชน   24            1            0            0
# ...        ...         ...  ...          ...          ...          ...
# 4027289    ชาย     ประชาชน   26            0            0            0
# 3381966   หญิง     ประชาชน   33            0            0            0
# 3708319   หญิง     ประชาชน   80            0            0            0
# 3662819   หญิง     ประชาชน   15            0            0            0
# 4026098   หญิง     ประชาชน   27            0            0            0
#
#          risk_group4  risk_group5  risk_group6  risk_group7  ...  st_5  ชาย  \
# ...

# %%
df.rename(
        columns=({ 'ชาย': 'male','หญิง': 'female','บุคคลากรทางการศึกษา':'peopleType2'
        ,'ประชาชน':'peopleType1','พระภิกษุ/สามเณร/นักบวช/ผู้นำศาสนา':'peopleType3','อสม':'peopleType4','เจ้าหน้าที่สาธารณสุข':'peopleType5'
        ,'เจ้าหน้าที่หน่วยงานสังกัดอื่น':'peopleType6','ผู้สัมผัสเสี่ยงสูง':'peopleType7'}),
        inplace=True,
)
df.head(3)
# Out:
#         gender people_type  age  risk_group1  risk_group2  risk_group3  \
# 2464369   หญิง     ประชาชน   13            0            0            0
# 2589400   หญิง     ประชาชน   25            0            0            0
# 2428662   หญิง     ประชาชน   15            0            0            0
#
#          risk_group4  risk_group5  risk_group6  risk_group7  ...  st_5  male  \
# 2464369            0            0            0            0  ...    10     0
# 2589400            0            0            0            0  ...    12     0
# 2428662            0            0            0            0  ...     8     0
#
#          female  peopleType2  peopleType1  peopleType7  peopleType3  \
# 2464369       1            0            1            0            0
# 2589400       1            0            1            0            0
# 2428662       1            0            1            0            0
#
#          peopleType4  peopleType5  peopleType6
# ...

# %%
df['age'] = \
    df['age']=df['age'].div(df['age'].max())   #แปลงค่าอายุ
df['age'] = df['age'].fillna(df['age'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย    

# df['q1'] = \
#     df['q1']=df['q1'].div(df['q1'].max()) #q1 
# df['q1'] = df['q1'].fillna(df['q1'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

# df['q7'] = \
#     df['q7']=df['q7'].div(df['q7'].max()) #q7 
# df['q7'] = df['q7'].fillna(df['q7'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

# df['q8'] = \
#     df['q8']=df['q8'].div(df['q8'].max()) #q8 
# df['q8'] = df['q8'].fillna(df['q8'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group1'] = \
    df['risk_group1']=df['risk_group1'].div(df['risk_group1'].max()) 
df['risk_group1'] = df['risk_group1'].fillna(df['risk_group1'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group2'] = \
    df['risk_group2']=df['risk_group2'].div(df['risk_group2'].max()) 
df['risk_group2'] = df['risk_group2'].fillna(df['risk_group2'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group3'] = \
    df['risk_group3']=df['risk_group3'].div(df['risk_group3'].max()) 
df['risk_group3'] = df['risk_group3'].fillna(df['risk_group3'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group4'] = \
    df['risk_group4']=df['risk_group4'].div(df['risk_group4'].max()) 
df['risk_group4'] = df['risk_group4'].fillna(df['risk_group4'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group5'] = \
    df['risk_group5']=df['risk_group5'].div(df['risk_group5'].max()) 
df['risk_group5'] = df['risk_group5'].fillna(df['risk_group5'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group6'] = \
    df['risk_group6']=df['risk_group6'].div(df['risk_group6'].max()) 
df['risk_group6'] = df['risk_group6'].fillna(df['risk_group6'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group7'] = \
    df['risk_group7']=df['risk_group7'].div(df['risk_group7'].max()) 
df['risk_group7'] = df['risk_group7'].fillna(df['risk_group7'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group8'] = \
    df['risk_group8']=df['risk_group8'].div(df['risk_group8'].max()) 
df['risk_group8'] = df['risk_group8'].fillna(df['risk_group8'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group12'] = \
    df['risk_group12']=df['risk_group12'].div(df['risk_group12'].max()) 
df['risk_group12'] = df['risk_group12'].fillna(df['risk_group12'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group13'] = \
    df['risk_group13']=df['risk_group13'].div(df['risk_group13'].max()) 
df['risk_group13'] = df['risk_group13'].fillna(df['risk_group13'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group14'] = \
    df['risk_group14']=df['risk_group14'].div(df['risk_group14'].max()) 
df['risk_group14'] = df['risk_group14'].fillna(df['risk_group14'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group15'] = \
    df['risk_group15']=df['risk_group15'].div(df['risk_group15'].max()) 
df['risk_group15'] = df['risk_group15'].fillna(df['risk_group15'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['risk_group16'] = \
    df['risk_group16']=df['risk_group16'].div(df['risk_group16'].max()) 
df['risk_group16'] = df['risk_group16'].fillna(df['risk_group16'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  




df['rq1'] = \
    df['rq1']=df['rq1'].div(df['rq1'].max()) #rq ข้อ 1
df['rq1'] = df['rq1'].fillna(df['rq1'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['rq2'] = \
    df['rq2']=df['rq2'].div(df['rq2'].max()) #rq ข้อ 1
df['rq2'] = df['rq2'].fillna(df['rq2'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  

df['rq3'] = \
    df['rq3']=df['rq3'].div(df['rq3'].max()) #rq ข้อ 1
df['rq3'] = df['rq3'].fillna(df['rq3'].mean()) #แทนค่าว่างด้วยค่าเฉลี่ย  


df['st_5'] = df['st_5'].fillna(0) #แทนค่าว่างด้วยค่า0
df.loc[df['st_5'] < 8, 'st_5_len'] = 0
df.loc[df['st_5'] >= 8, 'st_5_len'] = 1

df2=df[['st_5_len']]  #เลือกข้อมูล test

df.head()
# Out:
#         gender people_type   age  risk_group1  risk_group2  risk_group3  \
# 2464369   หญิง     ประชาชน  0.13          0.0          0.0          0.0
# 2589400   หญิง     ประชาชน  0.25          0.0          0.0          0.0
# 2428662   หญิง     ประชาชน  0.15          0.0          0.0          0.0
# 4020730    ชาย     ประชาชน  0.32          0.0          1.0          0.0
# 4393684   หญิง     ประชาชน  0.24          1.0          0.0          0.0
#
#          risk_group4  risk_group5  risk_group6  risk_group7  ...  male  \
# 2464369          0.0          0.0          0.0          0.0  ...     0
# 2589400          0.0          0.0          0.0          0.0  ...     0
# 2428662          0.0          0.0          0.0          0.0  ...     0
# 4020730          0.0          0.0          0.0          0.0  ...     1
# 4393684          0.0          0.0          0.0          0.0  ...     0
#
#          female  peopleType2  peopleType1  peopleType7  peopleType3  \
# ...

# %%
df.columns
# Out:
# Index(['gender', 'people_type', 'age', 'risk_group1', 'risk_group2',
#        'risk_group3', 'risk_group4', 'risk_group5', 'risk_group6',
#        'risk_group7', 'risk_group8', 'risk_group9', 'risk_group10',
#        'risk_group11', 'risk_group12', 'risk_group13', 'risk_group14',
#        'risk_group15', 'risk_group16', 'risk_group17', 'rq1', 'rq2', 'rq3',
#        'st_5', 'male', 'female', 'peopleType2', 'peopleType1', 'peopleType7',
#        'peopleType3', 'peopleType4', 'peopleType5', 'peopleType6', 'st_5_len'],
#       dtype='object')

# %%
X=df.drop('st_5', 1)
#X=X.drop('st_5_len', 1)
X=X.drop('people_type', 1)
X=X.drop('gender', 1)
X[0:50]
# Out:
# <ipython-input-73-6fb5ac8b3879>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X=df.drop('st_5', 1)
# <ipython-input-73-6fb5ac8b3879>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X=X.drop('people_type', 1)
# <ipython-input-73-6fb5ac8b3879>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X=X.drop('gender', 1)
#           age  risk_group1  risk_group2  risk_group3  risk_group4  \
# 2464369  0.13          0.0          0.0          0.0          0.0
# 2589400  0.25          0.0          0.0          0.0          0.0
# 2428662  0.15          0.0          0.0          0.0          0.0
# 4020730  0.32          0.0          1.0          0.0          0.0
# 4393684  0.24          1.0          0.0          0.0          0.0
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn import metrics

# %%
X=X.drop('st_5_len', 1)
# Out:
# <ipython-input-75-ef814c95c871>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X=X.drop('st_5_len', 1)

# %%
df2[0:10]
# Out:
#          st_5_len
# 2464369       1.0
# 2589400       1.0
# 2428662       1.0
# 4020730       1.0
# 4393684       1.0
# 3450723       1.0
# 3513155       1.0
# 3667904       1.0
# 3075373       1.0
# 2441378       1.0

# %%
y=df2

# %%
X
# Out:
#           age  risk_group1  risk_group2  risk_group3  risk_group4  \
# 2464369  0.13          0.0          0.0          0.0          0.0
# 2589400  0.25          0.0          0.0          0.0          0.0
# 2428662  0.15          0.0          0.0          0.0          0.0
# 4020730  0.32          0.0          1.0          0.0          0.0
# 4393684  0.24          1.0          0.0          0.0          0.0
# ...       ...          ...          ...          ...          ...
# 4027289  0.26          0.0          0.0          0.0          0.0
# 3381966  0.33          0.0          0.0          0.0          0.0
# 3708319  0.80          0.0          0.0          0.0          0.0
# 3662819  0.15          0.0          0.0          0.0          0.0
# 4026098  0.27          0.0          0.0          0.0          0.0
#
#          risk_group5  risk_group6  risk_group7  risk_group8  risk_group9  ...  \
# 2464369          0.0          0.0          0.0          0.0            0  ...
# ...

# %%
y
# Out:
#          st_5_len
# 2464369       1.0
# 2589400       1.0
# 2428662       1.0
# 4020730       1.0
# 4393684       1.0
# ...           ...
# 4027289       0.0
# 3381966       0.0
# 3708319       0.0
# 3662819       0.0
# 4026098       0.0
#
# [72800 rows x 1 columns]

# %%
#model= DecisionTreeClassifier(random_state=7)
model= RandomForestClassifier(n_estimators=250, random_state=7)
#model= ExtraTreesClassifier(n_estimators=250, random_state=7)

model.fit(X,y)
# Out:
# <ipython-input-80-ae6c99d6eb1a>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X,y)
# RandomForestClassifier(n_estimators=250, random_state=7)

# %%
model.feature_importances_
# Out:
# array([3.36036973e-01, 8.11897520e-03, 9.67983699e-03, 3.55425545e-03,
#        4.31628683e-03, 4.97095921e-03, 1.02414916e-02, 4.99628765e-03,
#        1.55183487e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.59315144e-03, 1.07483577e-02, 1.01943502e-02, 4.92908662e-03,
#        3.81363800e-03, 6.34835016e-03, 1.62596107e-01, 2.11783619e-01,
#        1.21678026e-01, 1.31539900e-02, 1.35572929e-02, 8.16411680e-03,
#        8.19029462e-03, 1.63492329e-03, 2.42162245e-04, 1.46581110e-02,
#        5.19211181e-03, 3.08889677e-03])

# %%
fs=pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=True)
fs
# Out:
# risk_group9     0.000000
# risk_group11    0.000000
# risk_group10    0.000000
# peopleType3     0.000242
# peopleType7     0.001635
# risk_group12    0.002593
# peopleType6     0.003089
# risk_group3     0.003554
# risk_group16    0.003814
# risk_group4     0.004316
# risk_group15    0.004929
# risk_group5     0.004971
# risk_group7     0.004996
# peopleType5     0.005192
# risk_group17    0.006348
# risk_group1     0.008119
# peopleType2     0.008164
# peopleType1     0.008190
# risk_group2     0.009680
# risk_group14    0.010194
# risk_group6     0.010241
# risk_group13    0.010748
# male            0.013154
# female          0.013557
# peopleType4     0.014658
# risk_group8     0.015518
# rq3             0.121678
# rq1             0.162596
# rq2             0.211784
# age             0.336037
# dtype: float64

# %%
fs.sum()
# Out:
# 0.9999999999999999

# %%
fs.plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
fs[fs > .1]
# Out:
# rq3    0.121678
# rq1    0.162596
# rq2    0.211784
# age    0.336037
# dtype: float64

# %%
fs.nlargest(4) #.index
# Out:
# age    0.336037
# rq2    0.211784
# rq1    0.162596
# rq3    0.121678
# dtype: float64

# %%
fs[fs > .1].index
# Out:
# Index(['rq3', 'rq1', 'rq2', 'age'], dtype='object')

# %%
X=df[fs[fs > .1].index]
X.head()
# Out:
#          rq3  rq1  rq2   age
# 2464369  0.7  0.7  0.6  0.13
# 2589400  0.5  0.3  0.3  0.25
# 2428662  1.0  1.0  1.0  0.15
# 4020730  0.1  0.1  0.3  0.32
# 4393684  0.2  0.1  0.1  0.24

# %%
# use stratify to split train/test
test_size=0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=test_size, 
                                                    stratify=y,
                                                    random_state=7)

# %%
algo=[
    [KNeighborsClassifier(n_neighbors=5), 'KNeighborsClassifier'], 
    [LogisticRegression(solver='lbfgs'), 'LogisticRegression'], 
    #[Perceptron(), 'Perceptron'],
    [DecisionTreeClassifier(min_samples_split=10), 'DecisionTreeClassifier'],
    #[GradientBoostingClassifier(), 'GradientBoostingClassifier'],
    [RandomForestClassifier(), 'RandomForestClassifier'],
    #[BaggingClassifier(), 'BaggingClassifier'],
    #[AdaBoostClassifier(), 'AdaBoostClassifier'],
    #[GaussianNB(), 'GaussianNB'],
    #[MLPClassifier(), 'MLPClassifier'],
    #[SVC(kernel='linear'), 'SVC_linear'], 
    #[GaussianProcessClassifier(), 'GaussianProcessClassifier']
]
model_scores=[]
for a in algo:
    model = a[0]
    model.fit(X_train, y_train)
    score=model.score(X_test, y_test)
    model_scores.append([score, a[1]])
    y_pred=model.predict(X_test)
    print(f'{a[1]:20} score: {score:.04f}')
    print(metrics.confusion_matrix(y_test, y_pred))
    print(metrics.classification_report(y_test, y_pred,digits=4))
    print('-' * 100)

print(model_scores)
print(f'best score = {max(model_scores)}')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:207: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier score: 0.8322
# [[6141 1139]
#  [1304 5976]]
#               precision    recall  f1-score   support
#
#          0.0     0.8248    0.8435    0.8341      7280
#          1.0     0.8399    0.8209    0.8303      7280
#
#     accuracy                         0.8322     14560
#    macro avg     0.8324    0.8322    0.8322     14560
# weighted avg     0.8324    0.8322    0.8322     14560
#
# ----------------------------------------------------------------------------------------------------
# LogisticRegression   score: 0.8284
# [[6111 1169]
#  [1330 5950]]
#               precision    recall  f1-score   support
#
#          0.0     0.8213    0.8394    0.8302      7280
# ...

# %%
model_scores
# Out:
# [[0.8322115384615385, 'KNeighborsClassifier'],
#  [0.8283653846153847, 'LogisticRegression'],
#  [0.8304258241758242, 'DecisionTreeClassifier'],
#  [0.8322115384615385, 'RandomForestClassifier']]

# %%
dscore=pd.DataFrame(model_scores, columns=['score', 'classifier'])
dscore.sort_values('score', ascending=False)
# Out:
#       score              classifier
# 0  0.832212    KNeighborsClassifier
# 3  0.832212  RandomForestClassifier
# 2  0.830426  DecisionTreeClassifier
# 1  0.828365      LogisticRegression
